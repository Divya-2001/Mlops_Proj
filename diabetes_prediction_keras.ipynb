# %%
# Load dataset 
import pandas as pd 
df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Now, we have to find out the main feature which leads to diabetes 
# Also, predict if a person is diabetic or not?

# %%
# Outcome is target variable 
y=df["Outcome"]

# %%
# Remaining are the features
# We drop Outcome column
X=df.drop(['Outcome'],axis=1)

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
# Creating model 
from keras.models import Sequential
model=Sequential()

# %%
# To add hidden layers, import Dense 
from keras.layers import Dense

# %%
# Adding 1st layer 
model.add(Dense(units=4,
                kernel_initializer="zeros",
                bias_initializer="zeros",
                activation="relu",
                input_dim=8
                ))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 20
# =================================================================
# Total params: 56
# Trainable params: 56
# Non-trainable params: 0
# _________________________________________________________________

# %%
# add 2nd layer 
# Now, 1st layer gives 4 output as it has 4 neurons so it will take 4 input and it will take it automatically 
model.add(Dense(units=4,
               activation="relu",
               bias_initializer="zeros",
               kernel_initializer="zeros"))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 20
# =================================================================
# Total params: 76
# Trainable params: 76
# Non-trainable params: 0
# _________________________________________________________________

# %%
# last final output layer 
# As our outcome is 0 or 1 i.e binary classification, so function we have to use is Sigmoid
model.add(Dense(units=1,
               activation="sigmoid",
               bias_initializer="zeros",
               kernel_initializer="zeros"))

# %%
# MODEL
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Now, we need to compile model 
# Defining Adam as Optimizer and loss function
# It is binary classification so we use cannot use MSE. MSE is for Regression problem. 
# For Binary Classification, we use binary_crossentropy
from keras.optimizers import Adam
model.compile(optimizer=Adam(), loss="binary_crossentropy")

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 13s 996us/step - loss: 0.6924
# Epoch 2/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6890
# Epoch 3/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6862
# Epoch 4/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6841
# Epoch 5/100
# 24/24 [==============================] - 0s 609us/step - loss: 0.6798
# Epoch 6/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6775
# Epoch 7/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6754
# Epoch 8/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6716
# Epoch 9/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6733
# Epoch 10/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6674
# Epoch 11/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6693
# Epoch 12/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6637
# Epoch 13/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6602
# Epoch 14/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6640
# Epoch 15/100
# 24/24 [==============================] - 0s 826us/step - loss: 0.6643
# Epoch 16/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6609
# Epoch 17/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6598
# Epoch 18/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6620
# Epoch 19/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6569
# Epoch 20/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6534
# Epoch 21/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6536
# Epoch 22/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6450
# Epoch 23/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6566
# Epoch 24/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6486
# Epoch 25/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6449
# Epoch 26/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6482
# Epoch 27/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6483
# Epoch 28/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6515
# Epoch 29/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6463
# Epoch 30/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6534
# Epoch 31/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6570
# Epoch 32/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6500
# Epoch 33/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6377
# Epoch 34/100
# 24/24 [==============================] - 0s 826us/step - loss: 0.6503
# Epoch 35/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6439
# Epoch 36/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6540
# Epoch 37/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6510
# Epoch 38/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6525
# Epoch 39/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6640
# Epoch 40/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6530
# Epoch 41/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6385
# Epoch 42/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6397
# Epoch 43/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6501
# Epoch 44/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6426
# Epoch 45/100
# 24/24 [==============================] - 0s 609us/step - loss: 0.6412
# Epoch 46/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6602
# Epoch 47/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6538
# Epoch 48/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6455
# Epoch 49/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6486
# Epoch 50/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6442
# Epoch 51/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6451
# Epoch 52/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6484
# Epoch 53/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6379
# Epoch 54/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6460
# Epoch 55/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6578
# Epoch 56/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6420
# Epoch 57/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6467
# Epoch 58/100
# 24/24 [==============================] - 0s 609us/step - loss: 0.6452
# Epoch 59/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6634
# Epoch 60/100
# 24/24 [==============================] - ETA: 0s - loss: 0.644 - 0s 696us/step - loss: 0.6499
# Epoch 61/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6571
# Epoch 62/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6487
# Epoch 63/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6556
# Epoch 64/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6374
# Epoch 65/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6435
# Epoch 66/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6418
# Epoch 67/100
# 24/24 [==============================] - 0s 913us/step - loss: 0.6416
# Epoch 68/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6562
# Epoch 69/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6538
# Epoch 70/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6391
# Epoch 71/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6512
# Epoch 72/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6528
# Epoch 73/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6442
# Epoch 74/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6392
# Epoch 75/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6449
# Epoch 76/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6493
# Epoch 77/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6546
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6480
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6550
# Epoch 80/100
# 24/24 [==============================] - 0s 826us/step - loss: 0.6306
# Epoch 81/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6412
# Epoch 82/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6393
# Epoch 83/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6426
# Epoch 84/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6682
# Epoch 85/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6410
# Epoch 86/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6597
# Epoch 87/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6175
# Epoch 88/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6445
# Epoch 89/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6442
# Epoch 90/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6341
# Epoch 91/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6527
# Epoch 92/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6318
# Epoch 93/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6393
# Epoch 94/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6428
# Epoch 95/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6490
# Epoch 96/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6489
# Epoch 97/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6453
# Epoch 98/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6519
# Epoch 99/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6682
# Epoch 100/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.6429
